# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import quandl

from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
currency = quandl.get("PERTH/AUD_USD_D", authtoken="w-mFq_xX3zLtSzvHM8vx")

# %%
currency.head()
# Out:
#             Bid High  Ask High  Bid Low  Ask Low  Bid Average  Ask Average
# Date
# 1991-06-21    0.7661    0.7668   0.7647   0.7654       0.7650       0.7657
# 1991-06-22    0.7650    0.7655   0.7640   0.7645       0.7645       0.7650
# 1991-06-24    0.7630    0.7645   0.7627   0.7634       0.7628       0.7637
# 1991-06-25    0.7655    0.7662   0.7647   0.7654       0.7650       0.7657
# 1991-06-26    0.7670    0.7677   0.7663   0.7670       0.7667       0.7674

# %%
currency.tail()
# Out:
#             Bid High  Ask High  Bid Low  Ask Low  Bid Average  Ask Average
# Date
# 2019-10-25    0.6830    0.6835   0.6810   0.6815       0.6820       0.6823
# 2019-10-28    0.6827    0.6828   0.6813   0.6814       0.6818       0.6819
# 2019-10-29    0.6854    0.6858   0.6836   0.6838       0.6847       0.6849
# 2019-10-30    0.6872    0.6874   0.6856   0.6857       0.6864       0.6865
# 2019-10-31    0.6926    0.6927   0.6899   0.6901       0.6918       0.6920

# %%
sns.pairplot(currency)
plt.show()

# %%
mask = np.zeros_like(currency_corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(15, 10))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(currency_corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

plt.show();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-0018926ccbb6> in <module>
# ----> 1 mask = np.zeros_like(currency_corr, dtype=np.bool)
#       2 mask[np.triu_indices_from(mask)] = True
#       3 f, ax = plt.subplots(figsize=(15, 10))
#       4
#       5 # Generate a custom diverging colormap
#
# NameError: name 'currency_corr' is not defined
